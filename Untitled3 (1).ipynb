# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("apex.csv")

# %%
df.head()
# Out:
#     Order_ID  Order_Date Customer_ID Customer_Name   Age  Gender       City  \
# 0  ORD100002   2/25/2025    CUST5529  Customer_227  30.0  Female  Bengaluru
# 1  ORD100003  10/14/2025    CUST3127  Customer_182  63.0    Male  Bengaluru
# 2  ORD100004   5/13/2025    CUST8887  Customer_487  62.0  Female  Bengaluru
# 3  ORD100005   12/2/2025    CUST2515  Customer_470  65.0  Female    Kolkata
# 4  ORD100006  11/20/2025    CUST4796  Customer_380  44.0    Male  Bengaluru
#
#   Product     Category  Quantity  Unit_Price  Total_Sales
# 0    Rice      Grocery         7     2829.77     19808.39
# 1    Book    Education         5    27906.16    139530.80
# 2    Book    Education         8    37491.06    299928.48
# 3  Mobile  Electronics         9    28541.36    256872.24
# 4    Rice      Grocery        10    14036.59    140365.90

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_ID       1000 non-null   object
#  1   Order_Date     1000 non-null   object
#  2   Customer_ID    1000 non-null   object
#  3   Customer_Name  1000 non-null   object
#  4   Age            993 non-null    float64
#  5   Gender         1000 non-null   object
#  6   City           987 non-null    object
#  7   Product        1000 non-null   object
#  8   Category       1000 non-null   object
#  9   Quantity       1000 non-null   int64
#  10  Unit_Price     1000 non-null   float64
#  11  Total_Sales    1000 non-null   float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 93.9+ KB

# %%
df.dtypes
# Out:
# Order_ID          object
# Order_Date        object
# Customer_ID       object
# Customer_Name     object
# Age              float64
# Gender            object
# City              object
# Product           object
# Category          object
# Quantity           int64
# Unit_Price       float64
# Total_Sales      float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Order_ID          0
# Order_Date        0
# Customer_ID       0
# Customer_Name     0
# Age               7
# Gender            0
# City             13
# Product           0
# Category          0
# Quantity          0
# Unit_Price        0
# Total_Sales       0
# dtype: int64

# %% [markdown]
# Data cleaning and Standarization

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df["Total_Sales"]=df["Total_Sales"].fillna(df["Total_Sales"].median())

# %%
df.shape
# Out:
# (1000, 12)

# %% [markdown]
# Exploratorary Data Analysis

# %%
df.describe()
# Out:
#               Age     Quantity    Unit_Price    Total_Sales
# count  993.000000  1000.000000   1000.000000    1000.000000
# mean    41.328298     5.435000  25486.783410  139399.439650
# std     13.773476     2.838632  14179.402361  114100.051546
# min     16.000000     1.000000    145.780000     437.340000
# 25%     30.000000     3.000000  13895.722500   47066.632500
# 50%     41.000000     5.000000  25398.740000  108594.025000
# 75%     53.000000     8.000000  37512.382500  203722.882500
# max     65.000000    10.000000  49997.530000  493677.500000

# %%
df["Category"].value_counts()
# Out:
# Category
# Electronics    354
# Education      178
# Furniture      159
# Fashion        156
# Grocery        153
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.histplot(df['Total_Sales'])
# Out:
# <Axes: xlabel='Total_Sales', ylabel='Count'>

# %%
sns.barplot(x=df['Category'],y=df['Total_Sales'])
# Out:
# <Axes: xlabel='Category', ylabel='Total_Sales'>

# %%
sns.boxplot(x=df['City'],y=df['Total_Sales'])
# Out:
# <Axes: xlabel='City', ylabel='Total_Sales'>

# %% [markdown]
# Multivariate Analysis

# %%
sns.scatterplot(x=df['Total_Sales'],y=df['Category'])
# Out:
# <Axes: xlabel='Total_Sales', ylabel='Category'>

# %%
sns.violinplot(x=df['Category'],y=df['Total_Sales'])
# Out:
# <Axes: xlabel='Category', ylabel='Total_Sales'>

# %%
sns.pairplot(df)
